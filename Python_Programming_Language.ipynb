# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
print(input("Enter a string"))
# Out:
# Enter a string welcome
# welcome

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
a = int(input("Enter a number"))
if (a==0):
    print("Zero")
if (a<0):
    print("Negative")
if (a>0):
    print("Positive")
# Out:
# Enter a number 34
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
a = int(input("a:"))
b = int(input("b:"))
c = int(input("c:"))
print("a:",a,"b:",b,"c:",c)
if a > b and a > c:
    print("a is the largest")
elif b > a and b > c:
    print("b is the largest")
elif c > a and c > b:
    print("c is the largest")
# Out:
# a: 34
# b: 5
# c: 67
# a: 34 b: 5 c: 67
# c is the largest

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

num = int(input("Enter a number: "))
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# Enter a number:  5
# The factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
a,ta = 4,type(a)
b,tb = 4.6,type(b)
c,tc = "Name or Somthing else",type(c)
d,td = True,type(d)
print(a,ta)
print(b,tb)
print(c,tc)
print(d,td)
# Out:
# 4 <class 'int'>
# 4.6 <class 'float'>
# Name or Somthing else <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# First Approach
a,b = 10,20
print(a,b)
a,b = b,a
print(a,b)
print("\n")
# Second approach
a,b = 10,20
print(a,b)
temp = a + b
a = temp - a
b = temp - b
print(a,b)
# Out:
# 10 20
# 20 10
#
#
# 10 20
# 20 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# 1 degree Celsius = 33.8 degree Fahrenheit
c = float(input("Enter degree Celsius value:"))
f = c * 33.8
print(c,f"Degree Celsius = ",f,f"Fahrenheit")
# Out:
# Enter degree Celsius value: 56
# 56.0 Degree Celsius =  1892.7999999999997 Fahrenheit

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = 'Welcome'
str2 = ' to Home'
conca = str1 + str2
print(conca)
# Out:
# Welcome to Home

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var1 = 10.5
if (var1, float):
    print(f"{var1} is a float")
else:
    print(f"{var1} is not a float")

# To check ohers use same way
# Out:
# 10.5 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a,b,c = 10,20,30
add = a + b + c
print(add)
sub = a - b - c
print(sub)
mul = a * b * c
print(mul)
div = a/b/c
print(div)
# Out:
# 60
# -40
# 6000
# 0.016666666666666666

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = int(input("a:"))
b = int(input("b:"))
c = int(input("c:"))
print("a:",a,"b:",b,"c:",c)
if a == b and a == c:
    print("a,b,c are equal")
elif a != b and a != c:
    print("a,b,c are not equal")
elif a > b and a > c:
    print("a is the largest")
elif b > a and b > c:
    print("b is the largest")
elif c > a and c > b:
    print("c is the largest")

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a,b = 5,10
if (a==5 and b==10):
    print("This is and operator")
if (a==5 or b==5):
    print("This is or operator")
if (a==50 or b==10):
    print("This is or operator")
if (a!=b):
    print("This is not operator")

# a = 5
# b = 3

# print(f"{a} == {b}: {a == b}")
# print(f"{a} != {b}: {a != b}")
# print(f"{a} > {b}: {a > b}")
# print(f"{a} < {b}: {a < b}")
# Out:
# This is and operator
# This is or operator
# This is or operator
# This is not operator
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
n = int(input("Enter a number:"))
print(f"Square of the number {n} is ",n*n)
# Out:
# Enter a number: 5
# Square of the number 5 is  25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
n = int(input("Enter a number:"))
if (n%2 == 0):
    print("Even")
else:
    print("Odd")

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
n = int(input("Enter a number: "))
sum_n = (n * (n + 1)) // 2
print(f"The sum of the first {n} natural numbers is {sum_n}")
# Out:
# Enter a number:  4
# The sum of the first 4 natural numbers is 10

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
y = int(input("Enter an year:"))
if (y%4 == 0 and y&100 ==0) or (y%400 ==0):
    print(f"{y} is a leap year")
else:
    print(f"{y} is a not leap year")
# Out:
# Enter an year: 2024
# 2024 is a not leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string = input("Enter a string: ")
reversed_string = string[::-1]
print(f"The reversed string is: {reversed_string}")
# Out:
# Enter a string:  12345678
# The reversed string is: 87654321

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = input("Enter a string: ")
if string == string[::-1]:
    print(f"{string} is a palindrome.")
else:
    print(f"{string} is not a palindrome.")
# Out:
# Enter a string:  1212
# 1212 is not a palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# Enter numbers separated by space:  2
# Sorted list: [2]
